# %%
import pandas as pd

# %%
df=pd.read_csv("sales_table.csv")

# %%
df
# Out:
#     Order ID           Category Sub-Category       Segment   Sales  Profit  \
# 0       1001         furniture       tables      consumer    909.0  2537.0
# 1       1002          FURNITURE       CHAIRS     CORPORATE  2786.0  2516.0
# 2       1003         furniture       tables     corporate   9435.0  -144.0
# 3       1004    office supplies      storage     consumer    988.0  -117.0
# 4       1005          FURNITURE       CHAIRS  HOME OFFICE    934.0  1798.0
# 5       1006         furniture       tables     corporate   9428.0  1218.0
# 6       1007    office supplies      storage  HOME OFFICE      NaN  2815.0
# 7       1008          FURNITURE       CHAIRS    corporate   7424.0   893.0
# 8       1009          FURNITURE       CHAIRS     CORPORATE  6014.0   -82.0
# 9       1010    office supplies      storage     consumer   6381.0  2971.0
# 10      1011         TECHNOLOGY  ACCESSORIES   home office  1211.0  2488.0
# ...

# %%
df.tail()
# Out:
#     Order ID           Category Sub-Category      Segment   Sales  Profit  \
# 45      1046         furniture       tables    corporate   1464.0   437.0
# 46      1047   office supplies       binders  home office  1660.0  1605.0
# 47      1048         technology      phones    corporate   8453.0   377.0
# 48      1049          FURNITURE       CHAIRS   corporate   9855.0  1860.0
# 49      1050          FURNITURE       CHAIRS     Consumer  7169.0   279.0
#
#     Quantity
# 45       3.0
# 46       NaN
# 47      18.0
# 48      16.0
# 49       4.0

# %%
df.head()
# Out:
#    Order ID          Category Sub-Category       Segment   Sales  Profit  \
# 0      1001        furniture       tables      consumer    909.0  2537.0
# 1      1002         FURNITURE       CHAIRS     CORPORATE  2786.0  2516.0
# 2      1003        furniture       tables     corporate   9435.0  -144.0
# 3      1004   office supplies      storage     consumer    988.0  -117.0
# 4      1005         FURNITURE       CHAIRS  HOME OFFICE    934.0  1798.0
#
#    Quantity
# 0       9.0
# 1       4.0
# 2      19.0
# 3       NaN
# 4       7.0

# %%
df.describe()
# Out:
#          Order ID        Sales       Profit   Quantity
# count    50.00000    47.000000    47.000000  47.000000
# mean   1025.50000  5351.063830  1139.744681  10.978723
# std      14.57738  2962.622431  1145.804435   5.612445
# min    1001.00000   819.000000  -498.000000   1.000000
# 25%    1013.25000  2684.500000   -23.500000   7.000000
# 50%    1025.50000  6014.000000  1143.000000  11.000000
# 75%    1037.75000  7726.000000  2229.500000  16.000000
# max    1050.00000  9855.000000  2971.000000  20.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Order ID      50 non-null     int64
#  1   Category      50 non-null     object
#  2   Sub-Category  50 non-null     object
#  3   Segment       50 non-null     object
#  4   Sales         47 non-null     float64
#  5   Profit        47 non-null     float64
#  6   Quantity      47 non-null     float64
# dtypes: float64(3), int64(1), object(3)
# memory usage: 2.9+ KB

# %%
df.isnull()
# Out:
#     Order ID  Category  Sub-Category  Segment  Sales  Profit  Quantity
# 0      False     False         False    False  False   False     False
# 1      False     False         False    False  False   False     False
# 2      False     False         False    False  False   False     False
# 3      False     False         False    False  False   False      True
# 4      False     False         False    False  False   False     False
# 5      False     False         False    False  False   False     False
# 6      False     False         False    False   True   False     False
# 7      False     False         False    False  False   False     False
# 8      False     False         False    False  False   False     False
# 9      False     False         False    False  False   False     False
# 10     False     False         False    False  False   False     False
# 11     False     False         False    False  False   False     False
# ...

# %%
df.isnull().sum()
# Out:
# Order ID        0
# Category        0
# Sub-Category    0
# Segment         0
# Sales           3
# Profit          3
# Quantity        3
# dtype: int64

# %%
df["Profit"].bfill()
# Out:
# 0     2537.0
# 1     2516.0
# 2     -144.0
# 3     -117.0
# 4     1798.0
# 5     1218.0
# 6     2815.0
# 7      893.0
# 8      -82.0
# 9     2971.0
# 10    2488.0
# 11    -178.0
# 12    1864.0
# 13    2208.0
# 14     -87.0
# 15     166.0
# 16    2374.0
# 17    1687.0
# 18     605.0
# 19    2952.0
# 20    1143.0
# 21    2440.0
# 22     510.0
# 23     510.0
# 24    1890.0
# 25    1587.0
# 26     529.0
# 27     529.0
# 28     529.0
# 29    2292.0
# 30     -44.0
# 31    -487.0
# 32     -65.0
# 33     126.0
# 34    -498.0
# 35     -42.0
# 36     486.0
# 37    2842.0
# 38    2202.0
# 39    1661.0
# 40    2593.0
# 41    2251.0
# 42      -5.0
# 43    -414.0
# 44    -471.0
# 45     437.0
# 46    1605.0
# 47     377.0
# 48    1860.0
# 49     279.0
# Name: Profit, dtype: float64

# %%
df['Sales']=df['Sales'].fillna(df['Sales'].mean())

# %%
df['Profit']=df['Profit'].fillna(df['Profit'].median())

# %%
df['Quantity']=df['Quantity'].fillna(df['Quantity'].mode())

# %%
df
# Out:
#     Order ID           Category Sub-Category       Segment       Sales  \
# 0       1001         furniture       tables      consumer    909.00000
# 1       1002          FURNITURE       CHAIRS     CORPORATE  2786.00000
# 2       1003         furniture       tables     corporate   9435.00000
# 3       1004    office supplies      storage     consumer    988.00000
# 4       1005          FURNITURE       CHAIRS  HOME OFFICE    934.00000
# 5       1006         furniture       tables     corporate   9428.00000
# 6       1007    office supplies      storage  HOME OFFICE   5351.06383
# 7       1008          FURNITURE       CHAIRS    corporate   7424.00000
# 8       1009          FURNITURE       CHAIRS     CORPORATE  6014.00000
# 9       1010    office supplies      storage     consumer   6381.00000
# 10      1011         TECHNOLOGY  ACCESSORIES   home office  1211.00000
# 11      1012         TECHNOLOGY  ACCESSORIES     consumer   6701.00000
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['Sales']=df['Sales'].fillna(df['Sales'].mean())

# %%
df
# Out:
#     Order ID           Category Sub-Category       Segment       Sales  \
# 0       1001         furniture       tables      consumer    909.00000
# 1       1002          FURNITURE       CHAIRS     CORPORATE  2786.00000
# 2       1003         furniture       tables     corporate   9435.00000
# 3       1004    office supplies      storage     consumer    988.00000
# 4       1005          FURNITURE       CHAIRS  HOME OFFICE    934.00000
# 5       1006         furniture       tables     corporate   9428.00000
# 6       1007    office supplies      storage  HOME OFFICE   5351.06383
# 7       1008          FURNITURE       CHAIRS    corporate   7424.00000
# 8       1009          FURNITURE       CHAIRS     CORPORATE  6014.00000
# 9       1010    office supplies      storage     consumer   6381.00000
# 10      1011         TECHNOLOGY  ACCESSORIES   home office  1211.00000
# 11      1012         TECHNOLOGY  ACCESSORIES     consumer   6701.00000
# ...

# %%
df['Sales']=df['Sales'].fillna(df['Sales'].median())

# %%
df
# Out:
#     Order ID           Category Sub-Category       Segment       Sales  \
# 0       1001         furniture       tables      consumer    909.00000
# 1       1002          FURNITURE       CHAIRS     CORPORATE  2786.00000
# 2       1003         furniture       tables     corporate   9435.00000
# 3       1004    office supplies      storage     consumer    988.00000
# 4       1005          FURNITURE       CHAIRS  HOME OFFICE    934.00000
# 5       1006         furniture       tables     corporate   9428.00000
# 6       1007    office supplies      storage  HOME OFFICE   5351.06383
# 7       1008          FURNITURE       CHAIRS    corporate   7424.00000
# 8       1009          FURNITURE       CHAIRS     CORPORATE  6014.00000
# 9       1010    office supplies      storage     consumer   6381.00000
# 10      1011         TECHNOLOGY  ACCESSORIES   home office  1211.00000
# 11      1012         TECHNOLOGY  ACCESSORIES     consumer   6701.00000
# ...

# %%
df['Sales']=df['Sales'].fillna(df['Sales'].mode())

# %%
df
# Out:
#     Order ID           Category Sub-Category       Segment       Sales  \
# 0       1001         furniture       tables      consumer    909.00000
# 1       1002          FURNITURE       CHAIRS     CORPORATE  2786.00000
# 2       1003         furniture       tables     corporate   9435.00000
# 3       1004    office supplies      storage     consumer    988.00000
# 4       1005          FURNITURE       CHAIRS  HOME OFFICE    934.00000
# 5       1006         furniture       tables     corporate   9428.00000
# 6       1007    office supplies      storage  HOME OFFICE   5351.06383
# 7       1008          FURNITURE       CHAIRS    corporate   7424.00000
# 8       1009          FURNITURE       CHAIRS     CORPORATE  6014.00000
# 9       1010    office supplies      storage     consumer   6381.00000
# 10      1011         TECHNOLOGY  ACCESSORIES   home office  1211.00000
# 11      1012         TECHNOLOGY  ACCESSORIES     consumer   6701.00000
# ...

# %%
df['Profit']=df['Profit'].fillna(df['Profit'].mean())

# %%
df
# Out:
#     Order ID           Category Sub-Category       Segment       Sales  \
# 0       1001         furniture       tables      consumer    909.00000
# 1       1002          FURNITURE       CHAIRS     CORPORATE  2786.00000
# 2       1003         furniture       tables     corporate   9435.00000
# 3       1004    office supplies      storage     consumer    988.00000
# 4       1005          FURNITURE       CHAIRS  HOME OFFICE    934.00000
# 5       1006         furniture       tables     corporate   9428.00000
# 6       1007    office supplies      storage  HOME OFFICE   5351.06383
# 7       1008          FURNITURE       CHAIRS    corporate   7424.00000
# 8       1009          FURNITURE       CHAIRS     CORPORATE  6014.00000
# 9       1010    office supplies      storage     consumer   6381.00000
# 10      1011         TECHNOLOGY  ACCESSORIES   home office  1211.00000
# 11      1012         TECHNOLOGY  ACCESSORIES     consumer   6701.00000
# ...

# %%
df['Profit']=df['Profit'].fillna(df['Profit'].median())

# %%
df
# Out:
#     Order ID           Category Sub-Category       Segment       Sales  \
# 0       1001         furniture       tables      consumer    909.00000
# 1       1002          FURNITURE       CHAIRS     CORPORATE  2786.00000
# 2       1003         furniture       tables     corporate   9435.00000
# 3       1004    office supplies      storage     consumer    988.00000
# 4       1005          FURNITURE       CHAIRS  HOME OFFICE    934.00000
# 5       1006         furniture       tables     corporate   9428.00000
# 6       1007    office supplies      storage  HOME OFFICE   5351.06383
# 7       1008          FURNITURE       CHAIRS    corporate   7424.00000
# 8       1009          FURNITURE       CHAIRS     CORPORATE  6014.00000
# 9       1010    office supplies      storage     consumer   6381.00000
# 10      1011         TECHNOLOGY  ACCESSORIES   home office  1211.00000
# 11      1012         TECHNOLOGY  ACCESSORIES     consumer   6701.00000
# ...

# %%
df['Profit']=df['Profit'].fillna(df['Profit'].mode())

# %%
df
# Out:
#     Order ID           Category Sub-Category       Segment       Sales  \
# 0       1001         furniture       tables      consumer    909.00000
# 1       1002          FURNITURE       CHAIRS     CORPORATE  2786.00000
# 2       1003         furniture       tables     corporate   9435.00000
# 3       1004    office supplies      storage     consumer    988.00000
# 4       1005          FURNITURE       CHAIRS  HOME OFFICE    934.00000
# 5       1006         furniture       tables     corporate   9428.00000
# 6       1007    office supplies      storage  HOME OFFICE   5351.06383
# 7       1008          FURNITURE       CHAIRS    corporate   7424.00000
# 8       1009          FURNITURE       CHAIRS     CORPORATE  6014.00000
# 9       1010    office supplies      storage     consumer   6381.00000
# 10      1011         TECHNOLOGY  ACCESSORIES   home office  1211.00000
# 11      1012         TECHNOLOGY  ACCESSORIES     consumer   6701.00000
# ...

# %%
df['Quantity']=df['Quantity'].fillna(df['Quantity'].mean())

# %%
df
# Out:
#     Order ID           Category Sub-Category       Segment       Sales  \
# 0       1001         furniture       tables      consumer    909.00000
# 1       1002          FURNITURE       CHAIRS     CORPORATE  2786.00000
# 2       1003         furniture       tables     corporate   9435.00000
# 3       1004    office supplies      storage     consumer    988.00000
# 4       1005          FURNITURE       CHAIRS  HOME OFFICE    934.00000
# 5       1006         furniture       tables     corporate   9428.00000
# 6       1007    office supplies      storage  HOME OFFICE   5351.06383
# 7       1008          FURNITURE       CHAIRS    corporate   7424.00000
# 8       1009          FURNITURE       CHAIRS     CORPORATE  6014.00000
# 9       1010    office supplies      storage     consumer   6381.00000
# 10      1011         TECHNOLOGY  ACCESSORIES   home office  1211.00000
# 11      1012         TECHNOLOGY  ACCESSORIES     consumer   6701.00000
# ...

# %%
df['Quantity']=df['Quantity'].fillna(df['Quantity'].median())

# %%
df
# Out:
#     Order ID           Category Sub-Category       Segment       Sales  \
# 0       1001         furniture       tables      consumer    909.00000
# 1       1002          FURNITURE       CHAIRS     CORPORATE  2786.00000
# 2       1003         furniture       tables     corporate   9435.00000
# 3       1004    office supplies      storage     consumer    988.00000
# 4       1005          FURNITURE       CHAIRS  HOME OFFICE    934.00000
# 5       1006         furniture       tables     corporate   9428.00000
# 6       1007    office supplies      storage  HOME OFFICE   5351.06383
# 7       1008          FURNITURE       CHAIRS    corporate   7424.00000
# 8       1009          FURNITURE       CHAIRS     CORPORATE  6014.00000
# 9       1010    office supplies      storage     consumer   6381.00000
# 10      1011         TECHNOLOGY  ACCESSORIES   home office  1211.00000
# 11      1012         TECHNOLOGY  ACCESSORIES     consumer   6701.00000
# ...

# %%
df['Quantity']=df['Quantity'].fillna(df['Quantity'].mode())

# %%
df
# Out:
#     Order ID           Category Sub-Category       Segment       Sales  \
# 0       1001         furniture       tables      consumer    909.00000
# 1       1002          FURNITURE       CHAIRS     CORPORATE  2786.00000
# 2       1003         furniture       tables     corporate   9435.00000
# 3       1004    office supplies      storage     consumer    988.00000
# 4       1005          FURNITURE       CHAIRS  HOME OFFICE    934.00000
# 5       1006         furniture       tables     corporate   9428.00000
# 6       1007    office supplies      storage  HOME OFFICE   5351.06383
# 7       1008          FURNITURE       CHAIRS    corporate   7424.00000
# 8       1009          FURNITURE       CHAIRS     CORPORATE  6014.00000
# 9       1010    office supplies      storage     consumer   6381.00000
# 10      1011         TECHNOLOGY  ACCESSORIES   home office  1211.00000
# 11      1012         TECHNOLOGY  ACCESSORIES     consumer   6701.00000
# ...

# %%
df["Category"]=df["Category"].str.strip().str.title()

# %%
df["Sub-Category"]=df["Sub-Category"].str.strip().str.title()
df["Segment"]=df["Segment"].str.strip().str.title()

# %%
df
# Out:
#     Order ID         Category Sub-Category      Segment       Sales  Profit  \
# 0       1001        Furniture       Tables     Consumer   909.00000  2537.0
# 1       1002        Furniture       Chairs    Corporate  2786.00000  2516.0
# 2       1003        Furniture       Tables    Corporate  9435.00000  -144.0
# 3       1004  Office Supplies      Storage     Consumer   988.00000  -117.0
# 4       1005        Furniture       Chairs  Home Office   934.00000  1798.0
# 5       1006        Furniture       Tables    Corporate  9428.00000  1218.0
# 6       1007  Office Supplies      Storage  Home Office  5351.06383  2815.0
# 7       1008        Furniture       Chairs    Corporate  7424.00000   893.0
# 8       1009        Furniture       Chairs    Corporate  6014.00000   -82.0
# 9       1010  Office Supplies      Storage     Consumer  6381.00000  2971.0
# 10      1011       Technology  Accessories  Home Office  1211.00000  2488.0
# ...
