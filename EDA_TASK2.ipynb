# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("profit_sales_analysis_dataset.csv")

# %%
df
# Out:
#     Transaction_ID         Category           Product  Unit_Price  Quantity  \
# 0                1      Electronics            Laptop        1200         2
# 1                2      Electronics           Monitor         350         5
# 2                3        Furniture      Office Chair         180         8
# 3                4        Furniture              Desk         300         4
# 4                5  Office Supplies     Printer Paper          25        20
# 5                6  Office Supplies              Pens          12        50
# 6                7      Electronics          Keyboard          75        12
# 7                8      Electronics             Mouse          40        15
# 8                9        Furniture         Bookshelf         250         3
# 9               10  Office Supplies          Notebook          18        30
# 10              11      Electronics        Headphones          90        10
# 11              12        Furniture           Cabinet         400         2
# 12              13  Office Supplies           Stapler          20        25
# 13              14      Electronics            Tablet         500         4
# 14              15        Furniture     Meeting Table         600         2
# 15              16  Office Supplies       File Folder          10        60
# 16              17      Electronics            Webcam         110         8
# 17              18        Furniture              Sofa         800         1
# 18              19  Office Supplies        Calculator          45        15
# 19              20      Electronics        Smartphone         700         3
# 20              21        Furniture    Filing Cabinet         220         5
# 21              22  Office Supplies        Marker Set          30        20
# 22              23      Electronics           Speaker         150         6
# 23              24        Furniture  Conference Chair         140        10
# 24              25  Office Supplies        Whiteboard         100         4
#
#     Discount_Percent   Sales  Profit  Profit_Margin_Percent  Cost
# 0                  5  2280.0   420.0              18.421053  1860
# 1                 10  1575.0   275.0              17.460317  1300
# 2                 15  1224.0   264.0              21.568627   960
# 3                  5  1140.0   220.0              19.298246   920
# 4                  0   500.0   120.0              24.000000   380
# 5                  5   570.0   170.0              29.824561   400
# 6                 10   810.0   180.0              22.222222   630
# 7                 15   510.0    95.0              18.627451   415
# 8                 20   600.0    70.0              11.666667   530
# 9                  5   513.0   153.0              29.824561   360
# 10                10   810.0   210.0              25.925926   600
# 11                25   600.0   -80.0             -13.333333   680
# 12                 0   500.0   150.0              30.000000   350
# 13                20  1600.0    40.0               2.500000  1560
# 14                10  1080.0   180.0              16.666667   900
# 15                 5   570.0   180.0              31.578947   390
# 16                15   748.0    88.0              11.764706   660
# 17                30   560.0  -240.0             -42.857143   800
# 18                10   607.5   112.5              18.518519   495
# 19                 5  1995.0   345.0              17.293233  1650
# 20                20   880.0    40.0               4.545455   840
# 21                10   540.0   140.0              25.925926   400
# 22                15   765.0    45.0               5.882353   720
# 23                25  1050.0   -50.0              -4.761905  1100
# 24                 5   380.0    80.0              21.052632   300

# %%
sns.histplot(df["Sales"],bins=8)
plt.title("Distribution of sales")
plt.show()

# %%
sns.histplot(df["Profit"],bins=8)
plt.title("Distribution of profit")
plt.show()

# %%
sns.boxplot(x=df["Sales"])
plt.title("Boxplot of Sales")
plt.show()

# %%
sns.boxplot(x=df["Profit"])
plt.title("Boxplot of profit")
plt.show()

# %%
sns.scatterplot(x='Discount_Percent', y='Profit_Margin_Percent', data=df)
plt.title('Discount vs Profit Margin')
plt.show()

# %%
sns.barplot(x='Discount_Percent', y='Profit_Margin_Percent', data=df)
plt.title('Discount vs Profit Margin')
plt.show()

# %%
numeric_cols=["Unit_Price","Quantity","Discount_Percent","Sales","Profit","Profit_Margin_Percent","Cost"]

# %%
alriya=df[numeric_cols].corr()

# %%
alriya
# Out:
#                        Unit_Price  Quantity  Discount_Percent     Sales  \
# Unit_Price               1.000000 -0.531752          0.218096  0.738126
# Quantity                -0.531752  1.000000         -0.451517 -0.408180
# Discount_Percent         0.218096 -0.451517          1.000000 -0.047893
# Sales                    0.738126 -0.408180         -0.047893  1.000000
# Profit                   0.148141  0.128398         -0.732778  0.575324
# Profit_Margin_Percent   -0.466126  0.519802         -0.855801 -0.026516
# Cost                     0.799954 -0.507977          0.173678  0.966904
#
#                          Profit  Profit_Margin_Percent      Cost
# Unit_Price             0.148141              -0.466126  0.799954
# Quantity               0.128398               0.519802 -0.507977
# Discount_Percent      -0.732778              -0.855801  0.173678
# Sales                  0.575324              -0.026516  0.966904
# Profit                 1.000000               0.757291  0.347596
# Profit_Margin_Percent  0.757291               1.000000 -0.266625
# Cost                   0.347596              -0.266625  1.000000

# %%
sns.heatmap(alriya,
            annot=True,
            cmap="coolwarm",
            cbar=False,
            square=True,
            linewidth=1)
plt.title("profit_margin")
plt.show()
